# %%
# VARIABLES
# CREAR VARIABLES
# nombre_variable = valor
libro = "Hola"
numero = 9
decimales = 9.5
verdadero = True
falso = False
# USAR VARIABLES
print(libro)
numero
# Out:
# Hola
# 9

# %%
str1 = 'Me gusta Python'
str1[3]
# Out:
# 'g'

# %%
var1 = "Hello"
var2 = "world"
var1 + " " + var2
# Out:
# 'Hello world'

# %%
var1 = "Hello"
var2 = "world"
print(var1,var2)
# Out:
# Hello world

# %%
[4,5,6] + [1,2,3]
# Out:
# [4, 5, 6, 1, 2, 3]

# %%
# ESTRUCTURAS DE DATOS
# LISTAS
lista = [1,2,3,4]
# TUPLAS
tupla = (1,2,3,4)
# CONJUNTOS SET
conjunto = {1,2,3,4,5,1}
# DICCIONARIOS
lista = [1,2,3,4]
diccionario = {0:1,1:2,2:3,3:4,"Hola":56565}
agenda = {"Luis":666666666,"Pepe":6565656565}
diccionario["Hola"]
agenda["Luis"]

# %%
lista = [1,2,3,1,2,3,4]
list(set(lista))
# Out:
# [1, 2, 3, 4]

# %%
lista.append(88)
lista
# Out:
# [1, 2, 3, 4, 88]

# %%
lista.insert(0,"Hola")
lista
# Out:
# ['Hola', 1, 2, 3, 4, 88]

# %%
# OPERADORES
# OPERADOR DE ASIGNACIÓN
nombre = "Patata"
# OPERADORES ARITMÉTICOS
6 + 5
9 - 2
6 * 2
9 / 2
9 // 2
9 ** 5
9 % 2
# OPERADORES COMPARACIÓN
6 == "6"
6 != "Hola"
6 > 2
6 < 2
6 >= 5
6 in [1,2,3,6,4]

# OPERADORES LÓGICOS
and
or
not
# Out:
# True

# %%
nuestra_velocidad = 121
maxima_velocidad = 120
if nuestra_velocidad < maxima_velocidad:
  print("Todo OK")
elif nuestra_velocidad == maxima_velocidad:
  print("Deja de acelerar")
else:
  print("Multita")
# Out:
# Multita
